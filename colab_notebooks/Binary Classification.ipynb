# %%
import os, pathlib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflowjs as tfjs

# %%
from google.colab import drive

drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Set seeds
np.random.seed(1)
tf.random.set_seed(1)

# %%
# Define parameters
batch_size = 32
height = 400
width = 400

init_train_ds = keras.preprocessing.image_dataset_from_directory(
    "drive/My Drive/CLASSIFY_BALANCED_BINARY",
    validation_split=0.2,
    image_size=(1000, 1000),
    subset="training",
    seed=1,
    batch_size=batch_size,
    label_mode="int",
    crop_to_aspect_ratio=True,
)

init_val_ds = keras.preprocessing.image_dataset_from_directory(
    "drive/My Drive/CLASSIFY_BALANCED_BINARY",
    validation_split=0.2,
    image_size=(1000, 1000),
    subset="validation",
    seed=1,
    batch_size=batch_size,
    label_mode="int",
    crop_to_aspect_ratio=True,
)

# Random crop
random_crop = keras.Sequential([keras.layers.RandomCrop(height, width, seed=1)])
train_ds = init_train_ds.map(lambda x, y: (random_crop(x), y))
# Center crop
center_crop = keras.Sequential([keras.layers.CenterCrop(height, width)])
val_ds = init_val_ds.map(lambda x, y: (center_crop(x), y))

#########################################################################################################################

base_model = keras.applications.Xception(
    include_top=False, weights="imagenet", input_shape=(height, width, 3)
)
# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(height, width, 3))
x = inputs

# Normalize
scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
x = scale_layer(x)

# The base model contains batchnorm layers. We want to keep them in inference mode when we unfreeze the base model for fine-tuning, so we make sure that the base_model is running in inference mode here.
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.5)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)


#########################################################################################################################


model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=["accuracy"],
)

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=150,
    callbacks=[
        keras.callbacks.EarlyStopping(monitor="loss", min_delta=0.001, patience=10)
    ],
)

# Unfreeze the base_model. Note that it keeps running in inference mode since we passed `training=False` when calling it. This means that the batchnorm layers will not update their batch statistics.
# This prevents the batchnorm layers from undoing all the training we've done so far.
base_model.trainable = True
model.compile(
    optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
    loss=keras.losses.BinaryCrossentropy(),
    metrics=["accuracy"],
)
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[
        keras.callbacks.EarlyStopping(monitor="loss", min_delta=0.001, patience=10)
    ],
)
# Out:
# Found 1872 files belonging to 2 classes.
# Using 1498 files for training.
# Found 1872 files belonging to 2 classes.
# Using 374 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications
# 47/47 [==============================] - 80s 2s/step - loss: 0.4000 - accuracy: 0.8164 - val_loss: 0.3737 - val_accuracy: 0.8209
# Epoch 3/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.3489 - accuracy: 0.8431 - val_loss: 0.3202 - val_accuracy: 0.8583
# Epoch 4/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.3154 - accuracy: 0.8558 - val_loss: 0.3150 - val_accuracy: 0.8717
# Epoch 5/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.3004 - accuracy: 0.8692 - val_loss: 0.2823 - val_accuracy: 0.8690
# Epoch 6/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.2427 - accuracy: 0.9059 - val_loss: 0.2607 - val_accuracy: 0.8663
# Epoch 7/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.2469 - accuracy: 0.8952 - val_loss: 0.2684 - val_accuracy: 0.8984
# Epoch 8/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.2228 - accuracy: 0.9179 - val_loss: 0.2385 - val_accuracy: 0.9011
# Epoch 9/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1976 - accuracy: 0.9252 - val_loss: 0.2282 - val_accuracy: 0.8984
# Epoch 10/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1968 - accuracy: 0.9199 - val_loss: 0.2452 - val_accuracy: 0.9011
# Epoch 11/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1623 - accuracy: 0.9366 - val_loss: 0.2146 - val_accuracy: 0.9091
# Epoch 12/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1871 - accuracy: 0.9292 - val_loss: 0.2278 - val_accuracy: 0.9091
# Epoch 13/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1514 - accuracy: 0.9446 - val_loss: 0.2057 - val_accuracy: 0.9091
# Epoch 14/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1700 - accuracy: 0.9332 - val_loss: 0.1938 - val_accuracy: 0.9118
# Epoch 15/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1398 - accuracy: 0.9433 - val_loss: 0.2027 - val_accuracy: 0.9171
# Epoch 16/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1413 - accuracy: 0.9506 - val_loss: 0.1770 - val_accuracy: 0.9251
# Epoch 17/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1411 - accuracy: 0.9479 - val_loss: 0.1786 - val_accuracy: 0.9225
# Epoch 18/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0915 - accuracy: 0.9693 - val_loss: 0.1806 - val_accuracy: 0.9278
# Epoch 19/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1212 - accuracy: 0.9573 - val_loss: 0.1787 - val_accuracy: 0.9225
# Epoch 20/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1054 - accuracy: 0.9599 - val_loss: 0.1795 - val_accuracy: 0.9332
# Epoch 21/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1080 - accuracy: 0.9593 - val_loss: 0.1834 - val_accuracy: 0.9251
# Epoch 22/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.1088 - accuracy: 0.9573 - val_loss: 0.1797 - val_accuracy: 0.9225
# Epoch 23/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0923 - accuracy: 0.9626 - val_loss: 0.2132 - val_accuracy: 0.9251
# Epoch 24/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0930 - accuracy: 0.9599 - val_loss: 0.2648 - val_accuracy: 0.9091
# Epoch 25/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0724 - accuracy: 0.9720 - val_loss: 0.1847 - val_accuracy: 0.9332
# Epoch 26/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0845 - accuracy: 0.9693 - val_loss: 0.2807 - val_accuracy: 0.9064
# Epoch 27/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0919 - accuracy: 0.9666 - val_loss: 0.1882 - val_accuracy: 0.9305
# Epoch 28/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0629 - accuracy: 0.9773 - val_loss: 0.2102 - val_accuracy: 0.9251
# Epoch 29/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0871 - accuracy: 0.9700 - val_loss: 0.2421 - val_accuracy: 0.9064
# Epoch 30/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0761 - accuracy: 0.9713 - val_loss: 0.1942 - val_accuracy: 0.9305
# Epoch 31/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0655 - accuracy: 0.9766 - val_loss: 0.1896 - val_accuracy: 0.9332
# Epoch 32/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0624 - accuracy: 0.9806 - val_loss: 0.2334 - val_accuracy: 0.9198
# Epoch 33/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0506 - accuracy: 0.9840 - val_loss: 0.1945 - val_accuracy: 0.9332
# Epoch 34/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0530 - accuracy: 0.9800 - val_loss: 0.1957 - val_accuracy: 0.9305
# Epoch 35/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0489 - accuracy: 0.9813 - val_loss: 0.1997 - val_accuracy: 0.9332
# Epoch 36/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0364 - accuracy: 0.9880 - val_loss: 0.2105 - val_accuracy: 0.9358
# Epoch 37/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0483 - accuracy: 0.9840 - val_loss: 0.2620 - val_accuracy: 0.9251
# Epoch 38/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0379 - accuracy: 0.9880 - val_loss: 0.2271 - val_accuracy: 0.9305
# Epoch 39/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0502 - accuracy: 0.9820 - val_loss: 0.2145 - val_accuracy: 0.9251
# Epoch 40/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0410 - accuracy: 0.9846 - val_loss: 0.2634 - val_accuracy: 0.9118
# Epoch 41/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0384 - accuracy: 0.9887 - val_loss: 0.2157 - val_accuracy: 0.9305
# Epoch 42/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0333 - accuracy: 0.9880 - val_loss: 0.2055 - val_accuracy: 0.9439
# Epoch 43/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0525 - accuracy: 0.9833 - val_loss: 0.2263 - val_accuracy: 0.9278
# Epoch 44/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0346 - accuracy: 0.9893 - val_loss: 0.2059 - val_accuracy: 0.9305
# Epoch 45/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0485 - accuracy: 0.9826 - val_loss: 0.2280 - val_accuracy: 0.9358
# Epoch 46/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0337 - accuracy: 0.9893 - val_loss: 0.2103 - val_accuracy: 0.9412
# Epoch 47/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0179 - accuracy: 0.9953 - val_loss: 0.2822 - val_accuracy: 0.9225
# Epoch 48/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0582 - accuracy: 0.9780 - val_loss: 0.2341 - val_accuracy: 0.9225
# Epoch 49/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0316 - accuracy: 0.9880 - val_loss: 0.1983 - val_accuracy: 0.9385
# Epoch 50/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0429 - accuracy: 0.9873 - val_loss: 0.2191 - val_accuracy: 0.9305
# Epoch 51/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0300 - accuracy: 0.9893 - val_loss: 0.2031 - val_accuracy: 0.9385
# Epoch 52/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0313 - accuracy: 0.9907 - val_loss: 0.2171 - val_accuracy: 0.9385
# Epoch 53/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0379 - accuracy: 0.9873 - val_loss: 0.2026 - val_accuracy: 0.9439
# Epoch 54/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0204 - accuracy: 0.9953 - val_loss: 0.2240 - val_accuracy: 0.9305
# Epoch 55/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0214 - accuracy: 0.9940 - val_loss: 0.2077 - val_accuracy: 0.9385
# Epoch 56/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 0.2101 - val_accuracy: 0.9439
# Epoch 57/100
# 47/47 [==============================] - 80s 2s/step - loss: 0.0231 - accuracy: 0.9933 - val_loss: 0.2292 - val_accuracy: 0.9358

# %%
model.save("drive/My Drive/Models/BINARY")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
